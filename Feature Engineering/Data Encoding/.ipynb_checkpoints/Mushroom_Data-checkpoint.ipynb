# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('mushrooms.csv')

# %% [markdown]
# # Step 1
# Basic Questions on data

# %%
df.sample(4)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 7226     e         x           s         g       f    n               f
# 2086     e         f           f         n       f    n               f
# 1961     e         x           f         g       f    n               f
# 5692     e         k           y         p       t    n               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 7226            w         b          p  ...                        s
# 2086            w         b          h  ...                        f
# 1961            w         b          h  ...                        f
# 5692            c         b          w  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 7226                      w                      w         p          w
# 2086                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
(df['stalk-color-above-ring'] != df['stalk-color-below-ring']).sum()
# Out:
# np.int64(3056)

# %%
df.describe()

# %% [markdown]
# # Step 2
# ## Uni and Bi variant Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df , x='habitat' , hue = 'class')
# Out:
# <Axes: xlabel='habitat', ylabel='count'>

# %%
sns.countplot(data=df , x='population' , hue = 'class')
# Out:
# <Axes: xlabel='population', ylabel='count'>

# %%
sns.countplot(data=df , x='spore-print-color' , hue = 'class')
# Out:
# <Axes: xlabel='spore-print-color', ylabel='count'>

# %%
sns.countplot(data=df , x='ring-type' , hue = 'class')
# Out:
# <Axes: xlabel='ring-type', ylabel='count'>

# %%
sns.countplot(data=df , x='ring-number' , hue = 'class')
# Out:
# <Axes: xlabel='ring-number', ylabel='count'>

# %%
sns.countplot(data=df , x='veil-color' , hue = 'class')
# Out:
# <Axes: xlabel='veil-color', ylabel='count'>

# %%
sns.countplot(data=df , x='veil-type' , hue = 'class')
# Out:
# <Axes: xlabel='veil-type', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-color-above-ring' , hue = 'class')
# Out:
# <Axes: xlabel='stalk-color-above-ring', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-color-below-ring' )
# Out:
# <Axes: xlabel='stalk-color-below-ring', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-color-below-ring' , hue = 'class')
# Out:
# <Axes: xlabel='stalk-color-below-ring', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-surface-below-ring' , hue = 'class')
# Out:
# <Axes: xlabel='stalk-surface-below-ring', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-surface-above-ring' , hue = 'class')
# Out:
# <Axes: xlabel='stalk-surface-above-ring', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-root' , hue = 'class')
# Out:
# <Axes: xlabel='stalk-root', ylabel='count'>

# %%
sns.countplot(data=df , x='stalk-shape' , hue = 'class')
# Out:
# <Axes: xlabel='stalk-shape', ylabel='count'>

# %%
sns.countplot(data=df , x='bruises' , hue = 'class')
# Out:
# <Axes: xlabel='bruises', ylabel='count'>

# %%
sns.countplot(data=df , x='gill-color' , hue = 'class')
# Out:
# <Axes: xlabel='gill-color', ylabel='count'>

# %%
sns.countplot(data=df , x='gill-size' , hue = 'class')
# Out:
# <Axes: xlabel='gill-size', ylabel='count'>

# %%
sns.countplot(data=df , x='gill-spacing' , hue = 'class')
# Out:
# <Axes: xlabel='gill-spacing', ylabel='count'>

# %%
sns.countplot(data=df , x='gill-attachment' , hue = 'class')
# Out:
# <Axes: xlabel='gill-attachment', ylabel='count'>

# %%
sns.countplot(data = df , x= 'odor', hue='class')
# Out:
# <Axes: xlabel='odor', ylabel='count'>

# %%
sns.countplot(data = df , x= 'odor')
# Out:
# <Axes: xlabel='odor', ylabel='count'>

# %%
sns.countplot(data=df , x = 'cap-color' , hue ='class')
# Out:
# <Axes: xlabel='cap-color', ylabel='count'>

# %%
sns.countplot(data=df , x = 'cap-color')
# Out:
# <Axes: xlabel='cap-color', ylabel='count'>

# %%
sns.countplot(data = df , x='cap-surface' , hue='class')
# Out:
# <Axes: xlabel='cap-surface', ylabel='count'>

# %%
sns.countplot(data = df , x='cap-surface')
# Out:
# <Axes: xlabel='cap-surface', ylabel='count'>

# %%
sns.countplot(data=df ,x='cap-shape')
# Out:
# <Axes: xlabel='cap-shape', ylabel='count'>

# %%
sns.countplot(data = df , x='cap-shape' , hue='class')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
grouped = df.groupby(['odor' ,  'habitat','class']).size().reset_index(name ='count')
sns.barplot(x="odor", y="count", hue="class", data=grouped ,ci=None)
# Out:
# C:\Users\BEST LAPTOP\AppData\Local\Temp\ipykernel_204\506502950.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="odor", y="count", hue="class", data=grouped ,ci=None)
# <Axes: xlabel='odor', ylabel='count'>

# %%
# Crosstab: odor vs gill-size with class counts
heatmap_data = pd.crosstab([df['odor'], df['gill-size']], df['class'])

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(heatmap_data, annot=True, fmt="d", cmap="YlGnBu")

plt.title("Heatmap of Odor & Gill-Size vs Class (Edible/Poisonous)")
plt.ylabel("Odor - Gill-Size")
plt.xlabel("Class (Edible/Poisonous)")
plt.show()

# %% [markdown]
# # Step 3
# # Encoding

# %%
# Remove Redantant Columns 
df.drop(['veil-type', 'veil-color' , 'ring-number' , 'stalk-shape' , 'gill-attachment'], axis = 1 , inplace=True)

# %%
from sklearn.preprocessing import OneHotEncoder , LabelEncoder , OrdinalEncoder

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(df.iloc[:,1:] , df.iloc[: , 0] ,test_size = 0.3,  random_state = 0 )

# %%
le = LabelEncoder()
ohe = OneHotEncoder()
oe = OrdinalEncoder()

# %%
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
ordinal_col = ['gill-size']
nominal_col = X_train.drop(columns = ordinal_col , axis= 1 ).columns

# %%
transformer = ColumnTransformer(
    transformers = [
        ('ohe' , OneHotEncoder(drop = 'first' , sparse_output = False) ,nominal_col ),
        ('oe' , OrdinalEncoder(categories=[['b' ,'n']]) , ordinal_col)
    ]
)

# %%
X_train
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 5314         x           s         w       t    f            c         b
# 2075         x           s         y       t    l            c         b
# 5165         f           s         w       t    f            c         b
# 1155         b           y         w       t    a            c         b
# 4448         x           y         y       f    f            c         b
# ...        ...         ...       ...     ...  ...          ...       ...
# 4931         x           y         e       t    n            c         b
# 3264         x           f         g       f    f            c         b
# 1653         x           s         g       f    n            w         b
# 2607         f           f         n       t    n            c         b
# 2732         x           y         g       t    n            c         b
#
#      gill-color stalk-root stalk-surface-above-ring stalk-surface-below-ring  \
# ...

# %%
X_train_enc = transformer.fit_transform(X_train)
X_test_enc = transformer.transform(X_test)
